# %%
import pickle 
import pandas as pd

# %%
r2_f2f_real = pickle.load(open('r2.f2f_predictions_results', 'rb'))
r2_f2f_synth = pickle.load(open('r2.f2f_predictions_results_synthetic', 'rb'))
r2_g2f_real = pickle.load(open('r2fraudgen.pickle', 'rb'))

# %%
r2_f2f_real
# Out:
#                       MLPRegressor(max_iter=2000, random_state=10)  \
# next_X_TERMINAL  {'mean': -4.39758621143578, 'std': 78.58573965...
# next_Y_TERMINAL  {'mean': 0.0354411187508586, 'std': 6.01328933...
# next_TX_AMOUNT   {'mean': 0.12312708604196916, 'std': 0.0247745...
#
#                                             Ridge(random_state=10)  \
# next_X_TERMINAL  {'mean': 0.1873698166896723, 'std': 0.01743926...
# next_Y_TERMINAL  {'mean': 0.9289712214348356, 'std': 0.00103381...
# next_TX_AMOUNT   {'mean': 0.1338081750815972, 'std': 0.02341505...
#
#                             RandomForestRegressor(random_state=10)  \
# next_X_TERMINAL  {'mean': 0.2095989200914265, 'std': 0.00838622...
# next_Y_TERMINAL  {'mean': 0.9266598532050462, 'std': 0.00086704...
# next_TX_AMOUNT   {'mean': 0.08495964220763637, 'std': 0.0757177...
#
#                                                              naive
# next_X_TERMINAL  mean       -6.548025e+08
# variance    8.917690e...
# ...

# %%
r2_f2f_synth
# Out:
#                       MLPRegressor(max_iter=2000, random_state=10)  \
# next_X_TERMINAL  {'mean': 0.9378262694818589, 'std': 0.00022957...
# next_Y_TERMINAL  {'mean': 0.9303491447240841, 'std': 0.00021736...
# next_TX_AMOUNT   {'mean': 0.8576067494506227, 'std': 0.00022683...
#
#                                             Ridge(random_state=10)  \
# next_X_TERMINAL  {'mean': 0.9136604200070385, 'std': 0.00022580...
# next_Y_TERMINAL  {'mean': 0.8992473768650691, 'std': 0.00026770...
# next_TX_AMOUNT   {'mean': 0.8551817069071473, 'std': 0.00022892...
#
#                             RandomForestRegressor(random_state=10)  \
# next_X_TERMINAL  {'mean': 0.9481318126661599, 'std': 0.00019895...
# next_Y_TERMINAL  {'mean': 0.9500482788345193, 'std': 0.00017393...
# next_TX_AMOUNT   {'mean': 0.8249436329429549, 'std': 0.00024619...
#
#                                                              naive
# next_X_TERMINAL  mean         -150.869702
# variance    46111.696...
# ...

# %%
r2_g2f_real
# Out:
#                       MLPRegressor(max_iter=2000, random_state=10)  \
# next_X_TERMINAL  {'mean': -0.9033302958087477, 'std': 0.5029053...
# next_Y_TERMINAL  {'mean': -0.02043042310898183, 'std': 0.000739...
# next_TX_AMOUNT   {'mean': -0.027722825272259503, 'std': 0.00165...
#
#                                             Ridge(random_state=10)  \
# next_X_TERMINAL  {'mean': -0.03094639428526856, 'std': 0.001103...
# next_Y_TERMINAL  {'mean': -0.014915109183044395, 'std': 0.00029...
# next_TX_AMOUNT   {'mean': -0.008175079588257798, 'std': 0.00031...
#
#                             RandomForestRegressor(random_state=10)  \
# next_X_TERMINAL  {'mean': -0.04668270070194185, 'std': 0.001829...
# next_Y_TERMINAL  {'mean': 0.008401763437709108, 'std': 0.000510...
# next_TX_AMOUNT   {'mean': -0.0033966817383089885, 'std': 0.0006...
#
#                                                              naive
# next_X_TERMINAL  mean       -9.710323e+07
# variance    6.410738e...
# ...

# %% [markdown]
# Check the tex file
